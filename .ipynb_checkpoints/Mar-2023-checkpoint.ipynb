# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("03-2023.csv")

# %%
df.head()
# Out:
#      Record ID     Activity date Call direction Call duration  \
# 0  31910814822  2023-03-01 04:07            NaN      00:01:17
# 1  31911226501  2023-03-01 04:08            NaN      00:01:13
# 2  31921670559  2023-03-01 08:29            NaN      00:13:13
# 3  31923361399  2023-03-01 09:11            NaN      00:41:08
# 4  31924760337  2023-03-01 09:25            NaN      00:00:43
#
#    hs_call_outcome Activity assigned to
# 0              NaN         Karen Parker
# 1              NaN         Karen Parker
# 2              NaN       Travis Fleming
# 3              NaN         Ray Levesque
# 4              NaN          Paol Guzman

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10821 entries, 0 to 10820
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Record ID             10821 non-null  int64
#  1   Activity date         10821 non-null  str
#  2   Call direction        377 non-null    str
#  3   Call duration         10017 non-null  str
#  4   hs_call_outcome       0 non-null      float64
#  5   Activity assigned to  10821 non-null  str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 896.6 KB

# %%
df1 = df.drop(columns=['hs_call_outcome','Record ID'])

# %%
df1['Activity date'] = pd.to_datetime(
    df1['Activity date'],
    format="%Y-%m-%d %H:%M",
    errors="coerce"
)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10821 entries, 0 to 10820
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         10821 non-null  datetime64[us]
#  1   Call direction        377 non-null    str
#  2   Call duration         10017 non-null  str
#  3   Activity assigned to  10821 non-null  str
# dtypes: datetime64[us](1), str(3)
# memory usage: 558.4 KB

# %% [markdown]
# # Call Count per day

# %%
df2 = df1.copy()

# %%
df2['date'] = df2['Activity date'].dt.date

# %%
df2.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2023-03-01 04:07:00            NaN      00:01:17         Karen Parker
# 1 2023-03-01 04:08:00            NaN      00:01:13         Karen Parker
# 2 2023-03-01 08:29:00            NaN      00:13:13       Travis Fleming
# 3 2023-03-01 09:11:00            NaN      00:41:08         Ray Levesque
# 4 2023-03-01 09:25:00            NaN      00:00:43          Paol Guzman
#
#          date
# 0  2023-03-01
# 1  2023-03-01
# 2  2023-03-01
# 3  2023-03-01
# 4  2023-03-01

# %%
daily_calls = (
    df2.groupby(df2['Activity date'].dt.date)
    .size()
    .reset_index(name='call_count')
    .rename(columns={'Activity date': 'date'})
)

# %%
daily_calls.head()
# Out:
#          date  call_count
# 0  2023-03-01         284
# 1  2023-03-02         262
# 2  2023-03-03         359
# 3  2023-03-04          21
# 4  2023-03-05           8

# %%
plt.figure()
plt.plot(daily_calls['date'], daily_calls['call_count'],color='blue')

plt.fill_between(daily_calls['date'], daily_calls['call_count'], color='orange', alpha=0.6)

plt.title("Daily Call Volume")
plt.xlabel("Date")
plt.ylabel("Number of Calls")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Count of Call in Weekdays

# %%
df1['day'] = df1['Activity date'].dt.day_name()

# %%
df1.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2023-03-01 04:07:00            NaN      00:01:17         Karen Parker
# 1 2023-03-01 04:08:00            NaN      00:01:13         Karen Parker
# 2 2023-03-01 08:29:00            NaN      00:13:13       Travis Fleming
# 3 2023-03-01 09:11:00            NaN      00:41:08         Ray Levesque
# 4 2023-03-01 09:25:00            NaN      00:00:43          Paol Guzman
#
#          day
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4  Wednesday

# %%
day_Counts = df1["day"].value_counts()
day_Counts.plot(kind='bar')
ax= day_Counts.plot(kind='bar')

for i,v in enumerate(day_Counts):
    ax.text(i, v+1, str(v), ha="center")

plt.title("count of calls in day")
plt.xlabel("day")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Inbound VS Outbound

# %%
IN_OUT_COUNT = df1['Call direction'].value_counts()
IN_OUT_COUNT.plot(kind='bar')
ax = IN_OUT_COUNT.plot(kind='bar')

for i,v in enumerate(IN_OUT_COUNT):
    ax.text(i,v+1, str(v), ha="center")

plt.title("Count Inbound & Outbound call")
plt.xlabel('IN OR OUT')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Count 00 Duration for Bound

# %%
N_B = df1[(df1['Call duration'] == "00:00:00")]

# %%
N_B_Counts = N_B['Call direction'].value_counts()
N_B_Counts.plot(kind="bar")
ax = N_B_Counts.plot(kind="bar")

for i,v in enumerate(N_B_Counts):
    ax.text(i, v+1, str(v), ha="center")

plt.title("Count 00 Duration for Bound")
plt.xlabel("Bound")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 N_B_Counts = N_B['Call direction'].value_counts()
# ----> 2 N_B_Counts.plot(kind="bar")
#       3 ax = N_B_Counts.plot(kind="bar")
#       5 for i,v in enumerate(N_B_Counts):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#      73 return plot_obj.result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:525, in MPLPlot.generate(self)
#     523 for ax in self.axes:
#     524     self._post_plot_logic_common(ax)
# --> 525     self._post_plot_logic(ax, self.data)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:2049, in BarPlot._post_plot_logic(self, ax, data)
#    2046 else:
#    2047     str_index = [pprint_thing(key) for key in range(data.shape[0])]
# -> 2049 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    2050 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    2052 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# # Call duration Null but have Call direction

# %%
df1[(df1['Call duration'].isnull()) & (df1['Call direction'].notnull())]
# Out:
#             Activity date Call direction Call duration Activity assigned to  \
# 29    2023-03-01 11:10:00       Outbound           NaN        Keith Antonio
# 556   2023-03-03 09:54:00       Outbound           NaN          Jinky Rance
# 717   2023-03-03 13:30:00       Outbound           NaN          Jinky Rance
# 843   2023-03-03 16:29:00       Outbound           NaN          Jinky Rance
# 1041  2023-03-06 12:34:00       Outbound           NaN        Keith Antonio
# 1111  2023-03-06 13:58:00       Outbound           NaN        Keith Antonio
# 1112  2023-03-06 13:59:00       Outbound           NaN        Keith Antonio
# 1340  2023-03-07 11:30:00       Outbound           NaN        Keith Antonio
# 1344  2023-03-07 11:32:00       Outbound           NaN        Keith Antonio
# 1111      Monday
# 1112      Monday
# 1340     Tuesday
# 1344     Tuesday
# 1350     Tuesday
# 1577     Tuesday
# 1723   Wednesday
# 2005   Wednesday
# 2217    Thursday
# 2324    Thursday
# 2721      Friday
# 3005      Monday
# 3195      Monday
# 3222      Monday
# 3308      Monday
# 3310      Monday
# 3314      Monday
# 3570     Tuesday
# 3640     Tuesday
# 3642     Tuesday
# 3796   Wednesday
# 3830   Wednesday
# 4112   Wednesday
# 4604    Thursday
# 5252      Sunday
# 5253      Sunday
# 5254      Sunday
# 5255      Sunday
# 5505      Monday
# 5513      Monday
# 6109     Tuesday
# 6111     Tuesday
# 6142     Tuesday
# 6230     Tuesday
# 6469     Tuesday
# 6470     Tuesday
# 6471     Tuesday
# 6650   Wednesday
# 6661   Wednesday
# 7155    Thursday
# 7465    Thursday
# 7466    Thursday
# 7473    Thursday
# 7695      Friday
# 8280      Monday
# 9007     Tuesday
# 9073     Tuesday
# 9079     Tuesday
# 9569   Wednesday
# 9570   Wednesday
# 9573   Wednesday
# 10119   Thursday

# %%
df4 = df1.copy()

# %%
df4.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2023-03-01 04:07:00            NaN      00:01:17         Karen Parker
# 1 2023-03-01 04:08:00            NaN      00:01:13         Karen Parker
# 2 2023-03-01 08:29:00            NaN      00:13:13       Travis Fleming
# 3 2023-03-01 09:11:00            NaN      00:41:08         Ray Levesque
# 4 2023-03-01 09:25:00            NaN      00:00:43          Paol Guzman
#
#          day
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4  Wednesday

# %%
df4['Call duration'] = (
    pd.to_timedelta(df4['Call duration'], errors = 'coerce')
    .dt.total_seconds()/60
)

# %%
(df4['Call duration'] == 0).sum()
# Out:
# 0

# %%
df4['Call duration'] = df4['Call duration'].fillna(0)

# %%
df4 = df4.dropna(subset = ['Call direction'])

# %%
(df4['Call duration'] == 0).sum()
# Out:
# 57

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 377 entries, 29 to 10775
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         377 non-null    datetime64[us]
#  1   Call direction        377 non-null    str
#  2   Call duration         377 non-null    float64
#  3   Activity assigned to  377 non-null    str
#  4   day                   377 non-null    str
# dtypes: datetime64[us](1), float64(1), str(3)
# memory usage: 27.8 KB

# %% [markdown]
# # Working Call Assigner

# %%
df1['Activity assigned to'].nunique()
# Out:
# 19

# %%
df1['Activity assigned to'].unique()
# Out:
# <ArrowStringArray>
# [       'Karen Parker',      'Travis Fleming',        'Ray Levesque',
#          'Paol Guzman',      'Cameron Dudley',        'Dioni Canega',
#        'Tommie Walker',      'David Banister',        'Andy Ramirez',
#        'Keith Antonio',         'Jinky Rance',        'David Valdez',
#          'Adrian Tran',           'Terry Kim',    'Vladimir Suparto',
#      'Ra’Saan Daniels', 'Demmie Rose Tamonan',          'Daniel Uli',
#     'Chrystel Manabat']
# Length: 19, dtype: str

# %%
ASSI_COUNT = df1['Activity assigned to'].value_counts().head(5)

ax = ASSI_COUNT.plot(kind='barh')

for i,v in enumerate(ASSI_COUNT):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 Call Assign")
plt.xlabel("Count")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Max Call Duration

# %%
df4['Call duration'].max()
# Out:
# 95.3

# %%
top5 = df4.nlargest(5, "Call duration")

ax = top5.set_index('Activity assigned to')['Call duration'].sort_values().plot(kind="barh")

for i, v in enumerate(top5["Call duration"].sort_values()):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 longest Call Duration")
plt.xlabel("Duration (minutes)")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Only Weekdays Call Volume

# %%
df3 = df1.copy()

# %%
df3 = df3[~df3['day'].isin(['Saturday', 'Sunday'])]

# %%
df3['day'].unique()
# Out:
# <ArrowStringArray>
# ['Wednesday', 'Thursday', 'Friday', 'Monday', 'Tuesday']
# Length: 5, dtype: str

# %%
week_day_calls=(
    df3.groupby(df3['Activity date'].dt.date)
    .size()
    .reset_index(name='call_count')
    .rename(columns={'Activity date': 'date'})
)

# %%
plt.figure()
plt.plot(week_day_calls['date'], week_day_calls['call_count'], color='blue')

plt.fill_between(week_day_calls['date'], week_day_calls['call_count'],color='green', alpha=0.6)

plt.title("Week Days Call Volume")
plt.xlabel("date")
plt.ylabel("Number of calls")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # WEEKEND TIME DURATION

# %%
df5=df4.copy()

# %%
df5 = df5[~df5['day'].isin(['Monday', 'Thursday', 'Friday', 'Wednesday', 'Tuesday'])]

# %%
df5.head()
# Out:
#            Activity date Call direction  Call duration Activity assigned to  \
# 906  2023-03-04 11:50:00       Outbound       1.250000         Ray Levesque
# 918  2023-03-04 16:20:00       Outbound      26.266667         Ray Levesque
# 2864 2023-03-11 09:01:00       Outbound      22.816667         Ray Levesque
# 2865 2023-03-11 09:25:00       Outbound       1.933333         Ray Levesque
# 2868 2023-03-11 16:02:00       Outbound       1.066667         Ray Levesque
#
#            day
# 906   Saturday
# 918   Saturday
# 2864  Saturday
# 2865  Saturday
# 2868  Saturday

# %%
top5 = df5.nlargest(5, "Call duration")

ax = top5.set_index("Activity assigned to")["Call duration"].sort_values().plot(kind="barh")

for i, v in enumerate(top5["Call duration"].sort_values()):
    ax.text(v + 0.1, i, str(v), va="center")

plt.title("Top 5 Longest Call Duration")
plt.xlabel("Duration (minutes)")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Top 5 Weekend Call Assigner

# %%
ASSI_COUNT = df5['Activity assigned to'].value_counts().head(5)

ax = ASSI_COUNT.plot(kind='barh')

for i,v in enumerate(ASSI_COUNT):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 Call Assign")
plt.xlabel("Count")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Average Call Duration

# %%
df4["Call duration"].mean()
# Out:
# 6.136206896551725

# %%
df4["Call duration"].median()
# Out:
# 1.2166666666666666

# %% [markdown]
# # Without Call Assigner Calls

# %%
df6 = df3.copy()

# %%
df6['month'] = df6['Activity date'].dt.month_name()

# %%
no_assigner_calls = df6[df6["Activity assigned to"].isna()]

# %%
month_counts = no_assigner_calls["month"].value_counts()
month_counts.plot(kind="bar")
ax = month_counts.plot(kind="bar")

for i, v in enumerate(month_counts):
    ax.text(i, v + 1, str(v), ha="center")

plt.title("Count of calls Without Assigner")
plt.xlabel("Month")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[109], line 2
#       1 month_counts = no_assigner_calls["month"].value_counts()
# ----> 2 month_counts.plot(kind="bar")
#       3 ax = month_counts.plot(kind="bar")
#       5 for i, v in enumerate(month_counts):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#      73 return plot_obj.result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:525, in MPLPlot.generate(self)
#     523 for ax in self.axes:
#     524     self._post_plot_logic_common(ax)
# --> 525     self._post_plot_logic(ax, self.data)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:2049, in BarPlot._post_plot_logic(self, ax, data)
#    2046 else:
#    2047     str_index = [pprint_thing(key) for key in range(data.shape[0])]
# -> 2049 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    2050 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    2052 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# # Top 5 Peak Call date

# %%
daily_calls = df.groupby(df2["Activity date"].dt.date).size()

# %%
top5 = daily_calls.sort_values(ascending=False).head(5)

# %%
ax = top5.sort_index().plot(kind="bar", color="brown")

for i, v in enumerate(top5.sort_index()):
    ax.text(i, v + 0.5, str(v), ha="center", fontsize=10)
    
plt.title("Top 5 Peak Call Count In MAR 2023")
plt.xlabel("Date")
plt.ylabel("Call Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
