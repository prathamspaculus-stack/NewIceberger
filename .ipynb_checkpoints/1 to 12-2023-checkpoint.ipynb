# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("01-2023.csv")
df2 = pd.read_csv("02-2023.csv")
df3 = pd.read_csv("03-2023.csv")
df4 = pd.read_csv("04-2023.csv")
df5 = pd.read_csv("05-2023.csv")
df6 = pd.read_csv("06-2023.csv")
df7 = pd.read_csv("07-2023.csv")
df8 = pd.read_csv("08-2023.csv")
df9 = pd.read_csv("09-2023.csv")
df10 = pd.read_csv("10-2023.csv")
df11 = pd.read_csv("11-2023.csv")
df12 = pd.read_csv("12-2023.csv")

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7 ,df8, df9, df10, df11, df12], ignore_index=True)

# %%
df
# Out:
#           Record ID     Activity date Call direction Call duration  \
# 0       29440312866  2023-01-01 12:00            NaN      00:02:06
# 1       29444061847  2023-01-01 16:42            NaN           NaN
# 2       29444240240  2023-01-01 16:48            NaN           NaN
# 3       29444260139  2023-01-01 16:54            NaN           NaN
# 4       29444240665  2023-01-01 16:57            NaN           NaN
# ...             ...               ...            ...           ...
# 119539  44961751905  2023-12-30 09:36            NaN      00:15:30
# 119540  44965528936  2023-12-30 14:07            NaN      00:00:42
# 119541  44966993983  2023-12-30 14:08            NaN      00:00:38
# 119542  44968070552  2023-12-30 16:05            NaN      00:00:27
# 119543  44968110903  2023-12-30 16:06            NaN      00:00:24
#
#         hs_call_outcome Activity assigned to
# 0                   NaN         Ray Levesque
# 1                   NaN       David Banister
# 2                   NaN       David Banister
# 3                   NaN       David Banister
# 4                   NaN       David Banister
# ...                 ...                  ...
# 119539              NaN          Adrian Tran
# 119540              NaN        Sam Steindorf
# 119541              NaN        Sam Steindorf
# 119542              NaN        Sam Steindorf
# 119543              NaN        Sam Steindorf
#
# [119544 rows x 6 columns]

# %%
df1 = df.drop(columns=['hs_call_outcome', 'Record ID'])

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119544 entries, 0 to 119543
# Data columns (total 4 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Activity date         119544 non-null  str
#  1   Call direction        5695 non-null    str
#  2   Call duration         111613 non-null  str
#  3   Activity assigned to  119516 non-null  str
# dtypes: str(4)
# memory usage: 7.8 MB

# %%
df1['Activity date'] = pd.to_datetime(
    df1['Activity date'],
    format="%Y-%m-%d %H:%M",
    errors="coerce"
)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119544 entries, 0 to 119543
# Data columns (total 4 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Activity date         119544 non-null  datetime64[us]
#  1   Call direction        5695 non-null    str
#  2   Call duration         111613 non-null  str
#  3   Activity assigned to  119516 non-null  str
# dtypes: datetime64[us](1), str(3)
# memory usage: 6.0 MB

# %% [markdown]
# # Call Count per day

# %%
df2 = df1.copy()

# %%
df2['date'] = df2['Activity date'].dt.date

# %%
df2.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2023-01-01 12:00:00            NaN      00:02:06         Ray Levesque
# 1 2023-01-01 16:42:00            NaN           NaN       David Banister
# 2 2023-01-01 16:48:00            NaN           NaN       David Banister
# 3 2023-01-01 16:54:00            NaN           NaN       David Banister
# 4 2023-01-01 16:57:00            NaN           NaN       David Banister
#
#          date
# 0  2023-01-01
# 1  2023-01-01
# 2  2023-01-01
# 3  2023-01-01
# 4  2023-01-01

# %%
daily_calls = (
    df2.groupby(df2['Activity date'].dt.date)
    .size()
    .reset_index(name='call_count')
    .rename(columns={'Activity date' : 'date'})
)

# %%
daily_calls.tail(6)
# Out:
#            date  call_count
# 358  2023-12-25           2
# 359  2023-12-26         373
# 360  2023-12-27         305
# 361  2023-12-28         351
# 362  2023-12-29         132
# 363  2023-12-30           6

# %%
plt.figure()
plt.plot(daily_calls['date'], daily_calls['call_count'], color='blue')

plt.fill_between(daily_calls['date'], daily_calls['call_count'], color = 'green', alpha=0.4)

plt.title('Daily Call Count Volume')
plt.xlabel("Date")
plt.ylabel("Number of Calls")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df1.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to
# 0 2023-01-01 12:00:00            NaN      00:02:06         Ray Levesque
# 1 2023-01-01 16:42:00            NaN           NaN       David Banister
# 2 2023-01-01 16:48:00            NaN           NaN       David Banister
# 3 2023-01-01 16:54:00            NaN           NaN       David Banister
# 4 2023-01-01 16:57:00            NaN           NaN       David Banister

# %% [markdown]
# # Count of Call in Weekdays

# %%
df1['day'] = df1['Activity date'].dt.day_name()

# %%
df1.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2023-01-01 12:00:00            NaN      00:02:06         Ray Levesque
# 1 2023-01-01 16:42:00            NaN           NaN       David Banister
# 2 2023-01-01 16:48:00            NaN           NaN       David Banister
# 3 2023-01-01 16:54:00            NaN           NaN       David Banister
# 4 2023-01-01 16:57:00            NaN           NaN       David Banister
#
#       day
# 0  Sunday
# 1  Sunday
# 2  Sunday
# 3  Sunday
# 4  Sunday

# %%
day_Counts = df1["day"].value_counts()
day_Counts.plot(kind='bar')
ax = day_Counts.plot(kind='bar')

for i,v in enumerate(day_Counts):
    ax.text(i,v+1, str(v), ha= "center")

plt.title("count of calls in day")
plt.xlabel("day")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Inbound VS Outbound

# %%
IN_OUT_COUNT = df1['Call direction'].value_counts()
IN_OUT_COUNT.plot(kind='bar')
ax = IN_OUT_COUNT.plot(kind='bar')

for i,v in enumerate(IN_OUT_COUNT):
    ax.text(i,v+1, str(v), ha="center")

plt.title("Count Inbound & Outbound call")
plt.xlabel('IN OR OUT')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Count 00 Duration for Bound

# %%
N_B = df1[(df1['Call duration'] == "00:00:00")]

# %%
N_B_Counts = N_B['Call direction'].value_counts()
N_B_Counts.plot(kind="bar")
ax = N_B_Counts.plot(kind="bar")

for i,v in enumerate(N_B_Counts):
    ax.text(i, v+1, str(v), ha="center")

plt.title("Count 00 Duration for Bound")
plt.xlabel("Bound")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Call duration NULL but have Call direction

# %%
df1[(df1['Call duration'].isnull()) & (df1['Call direction'].notnull())]
# Out:
#              Activity date Call direction Call duration Activity assigned to  \
# 70     2023-01-03 11:28:00       Outbound           NaN        Keith Antonio
# 71     2023-01-03 11:29:00       Outbound           NaN        Keith Antonio
# 72     2023-01-03 11:31:00       Outbound           NaN        Keith Antonio
# 73     2023-01-03 11:33:00       Outbound           NaN        Keith Antonio
# 74     2023-01-03 11:35:00       Outbound           NaN        Keith Antonio
# ...                    ...            ...           ...                  ...
# 119340 2023-12-28 15:28:00        Inbound           NaN         Robin Stoehr
# 119351 2023-12-28 16:44:00       Outbound           NaN        Keith Antonio
# 119353 2023-12-28 16:48:00       Outbound           NaN        Keith Antonio
# 119354 2023-12-28 16:50:00       Outbound           NaN        Keith Antonio
# 119360 2023-12-28 18:04:00        Inbound           NaN         Robin Stoehr
#
#              day
# 70       Tuesday
# 71       Tuesday
# 72       Tuesday
# 73       Tuesday
# 74       Tuesday
# ...          ...
# 119340  Thursday
# 119351  Thursday
# 119353  Thursday
# 119354  Thursday
# 119360  Thursday
#
# [1435 rows x 5 columns]

# %%
df4 = df1.copy()

# %%
df4.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2023-01-01 12:00:00            NaN      00:02:06         Ray Levesque
# 1 2023-01-01 16:42:00            NaN           NaN       David Banister
# 2 2023-01-01 16:48:00            NaN           NaN       David Banister
# 3 2023-01-01 16:54:00            NaN           NaN       David Banister
# 4 2023-01-01 16:57:00            NaN           NaN       David Banister
#
#       day
# 0  Sunday
# 1  Sunday
# 2  Sunday
# 3  Sunday
# 4  Sunday

# %%
df4['Call duration'] = (
    pd.to_timedelta(df4['Call duration'], errors = 'coerce')
    .dt.total_seconds()/60
)

# %%
(df4['Call duration'] == 0).sum()
# Out:
# 17

# %%
df4['Call duration'].isnull().sum()
# Out:
# 7931

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119544 entries, 0 to 119543
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Activity date         119544 non-null  datetime64[us]
#  1   Call direction        5695 non-null    str
#  2   Call duration         111613 non-null  float64
#  3   Activity assigned to  119516 non-null  str
#  4   day                   119544 non-null  str
# dtypes: datetime64[us](1), float64(1), str(3)
# memory usage: 6.9 MB

# %%
df4['Call duration'] = df4['Call duration'].fillna(0)

# %%
df4 = df4.dropna(subset = ['Call direction'])

# %%
df4['Call duration'].isnull().sum()
# Out:
# 0

# %%
df4['Call direction'].isnull().sum()
# Out:
# 0

# %%
(df4['Call duration'] == 0).sum()
# Out:
# 1452

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5695 entries, 33 to 119513
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         5695 non-null   datetime64[us]
#  1   Call direction        5695 non-null   str
#  2   Call duration         5695 non-null   float64
#  3   Activity assigned to  5679 non-null   str
#  4   day                   5695 non-null   str
# dtypes: datetime64[us](1), float64(1), str(3)
# memory usage: 422.3 KB

# %% [markdown]
# # Working Call Assigner

# %%
df1['Activity assigned to'].nunique()
# Out:
# 39

# %%
df1['Activity assigned to'].unique()
# Out:
# <ArrowStringArray>
# [          'Ray Levesque',         'David Banister',         'Travis Fleming',
#               'Terry Kim',         'Cameron Dudley',           'Dioni Canega',
#                       nan,            'Paol Guzman',          'Keith Antonio',
#           'Tommie Walker',       'Vladimir Suparto',            'Jinky Rance',
#            'Karen Parker',       'Chrystel Manabat',        'Adonis Baybayan',
#        'Kent Encarnacion',             'Henry Good',           'Bill Goodwin',
#          'Branden Newman',           'John Meersma',             'Jacob Hess',
#             'Adrian Tran',         'Justin Schmidt',           'David Valdez',
#            'Andy Ramirez',           'Stephen Tarr',        'Ra’Saan Daniels',
#     'Demmie Rose Tamonan',             'Daniel Uli',        'Justin Bellware',
#  'Jannica Nikka Antipuna',       'Benjamin Sklivas',            'Sal Berdayi',
#            'Robin Stoehr',           'Louis Maciel',          'Oliver Martin',
#              'True Ellis',       'Colby Rintharamy',          'Pete Clements',
#           'Sam Steindorf']
# Length: 40, dtype: str

# %%
ASSI_COUNT = df1['Activity assigned to'].value_counts().head(5)

ax = ASSI_COUNT.plot(kind='barh')

for i,v in enumerate(ASSI_COUNT):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 Call Assign")
plt.xlabel("Count")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # MAX CALL DURATION

# %%
df4['Call duration'].max()
# Out:
# 118.58333333333333

# %%
top5 = df4.nlargest(5, "Call duration")

ax = top5.set_index('Activity assigned to')['Call duration'].sort_values().plot(kind="barh")

for i, v in enumerate(top5["Call duration"].sort_values()):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 longest Call Duration")
plt.xlabel("Duration (minutes)")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Only Week days Call Volume

# %%
df3=df1.copy()

# %%
df3 = df3[~df3['day'].isin(['Saturday', 'Sunday'])]

# %%
df3['day'].unique()
# Out:
# <ArrowStringArray>
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
# Length: 5, dtype: str

# %%
week_day_calls=(
    df3.groupby(df3['Activity date'].dt.date)
    .size()
    .reset_index(name='call_count')
    .rename(columns={'Activity date': 'date'})
)

# %%
plt.figure()
plt.plot(week_day_calls['date'], week_day_calls['call_count'], color='blue')

plt.fill_between(week_day_calls['date'], week_day_calls['call_count'],color='green', alpha=0.6)

plt.title("Week Days Call Volume")
plt.xlabel("date")
plt.ylabel("Number of calls")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # WEEKEND TIME DURATION

# %%
df5 = df4.copy()

# %%
df5 = df5[~df5['day'].isin(['Monday', 'Thursday', 'Friday', 'Wednesday', 'Tuesday'])]

# %%
df5.head()
# Out:
#           Activity date Call direction  Call duration Activity assigned to  \
# 802 2023-01-07 10:01:00       Outbound       1.450000         Ray Levesque
# 818 2023-01-07 11:54:00       Outbound       0.666667         Ray Levesque
# 823 2023-01-07 12:16:00       Outbound       1.683333         Ray Levesque
# 824 2023-01-07 12:40:00       Outbound      25.483333         Ray Levesque
# 842 2023-01-07 13:57:00       Outbound       7.433333         Ray Levesque
#
#           day
# 802  Saturday
# 818  Saturday
# 823  Saturday
# 824  Saturday
# 842  Saturday

# %%
top5 = df5.nlargest(5, "Call duration")

ax = top5.set_index("Activity assigned to")["Call duration"].sort_values().plot(kind="barh")

for i, v in enumerate(top5["Call duration"].sort_values()):
    ax.text(v + 0.1, i, str(v), va="center")

plt.title("Top 5 Longest Call Duration")
plt.xlabel("Duration (minutes)")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Top 5 Weekend Call Assigner

# %%
ASSI_COUNT = df5['Activity assigned to'].value_counts().head(5)

ax = ASSI_COUNT.plot(kind='barh')

for i,v in enumerate(ASSI_COUNT):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 Call Assign")
plt.xlabel("Count")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Monthly Call Count

# %%
df6 = df3.copy()

# %%
df6['month'] = df6['Activity date'].dt.month_name()

# %%
df6.head()
# Out:
#          Activity date Call direction Call duration Activity assigned to  \
# 15 2023-01-02 10:01:00            NaN      00:31:50       Travis Fleming
# 16 2023-01-02 10:20:00            NaN      00:04:20         Ray Levesque
# 17 2023-01-02 13:03:00            NaN           NaN       David Banister
# 18 2023-01-02 13:19:00            NaN           NaN       David Banister
# 19 2023-01-02 13:23:00            NaN           NaN       David Banister
#
#        day    month
# 15  Monday  January
# 16  Monday  January
# 17  Monday  January
# 18  Monday  January
# 19  Monday  January

# %%
month_counts = df6["month"].value_counts()
month_counts.plot(kind="bar")
ax = month_counts.plot(kind="bar")

for i, v in enumerate(month_counts):
    ax.text(i, v + 1, str(v), ha="center")

plt.title("Count of calls in month")
plt.xlabel("Month")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Average Call Duration

# %%
df4["Call duration"].mean()
# Out:
# 4.55753585016096

# %%
df4["Call duration"].median()
# Out:
# 0.9666666666666667

# %% [markdown]
# # WITHOUT CALL ASSIGNER CALLS

# %%
no_assigner_calls = df6[df6["Activity assigned to"].isna()]

# %%
no_assigner_calls.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 28 entries, 67 to 119416
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         28 non-null     datetime64[us]
#  1   Call direction        16 non-null     str
#  2   Call duration         28 non-null     str
#  3   Activity assigned to  0 non-null      str
#  4   day                   28 non-null     str
#  5   month                 28 non-null     str
# dtypes: datetime64[us](1), str(5)
# memory usage: 2.3 KB

# %%
month_counts = no_assigner_calls["month"].value_counts()
month_counts.plot(kind="bar")
ax = month_counts.plot(kind="bar")

for i, v in enumerate(month_counts):
    ax.text(i, v + 1, str(v), ha="center")

plt.title("Count of calls Without Assigner")
plt.xlabel("Month")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Top 5 PEAK CALL DATE

# %%
daily_calls = df.groupby(df2["Activity date"].dt.date).size()

# %%
top5 = daily_calls.sort_values(ascending=False).head(5)

# %%
ax = top5.sort_index().plot(kind="bar", color="brown")

for i, v in enumerate(top5.sort_index()):
    ax.text(i, v + 0.5, str(v), ha="center", fontsize=10)
    
plt.title("Top 5 Peak Call Count Dates")
plt.xlabel("Date")
plt.ylabel("Call Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
