# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("11-2023.csv")

# %%
df.head()
# Out:
#      Record ID     Activity date Call direction Call duration  \
# 0  42081627202  2023-11-01 00:52            NaN      00:00:40
# 1  42082259788  2023-11-01 00:53            NaN      00:00:25
# 2  42081337932  2023-11-01 00:53            NaN      00:00:12
# 3  42081580883  2023-11-01 00:54            NaN      00:00:21
# 4  42097263491  2023-11-01 09:13            NaN      00:01:00
#
#    hs_call_outcome Activity assigned to
# 0              NaN          Sal Berdayi
# 1              NaN          Sal Berdayi
# 2              NaN          Sal Berdayi
# 3              NaN          Sal Berdayi
# 4              NaN         Karen Parker

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13010 entries, 0 to 13009
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Record ID             13010 non-null  int64
#  1   Activity date         13010 non-null  str
#  2   Call direction        738 non-null    str
#  3   Call duration         12579 non-null  str
#  4   hs_call_outcome       0 non-null      float64
#  5   Activity assigned to  13010 non-null  str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 1.1 MB

# %%
df1 = df.drop(columns=['hs_call_outcome','Record ID'])

# %%
df1['Activity date'] = pd.to_datetime(
    df1['Activity date'],
    format="%Y-%m-%d %H:%M",
    errors="coerce"
)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13010 entries, 0 to 13009
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         13010 non-null  datetime64[us]
#  1   Call direction        738 non-null    str
#  2   Call duration         12579 non-null  str
#  3   Activity assigned to  13010 non-null  str
# dtypes: datetime64[us](1), str(3)
# memory usage: 677.0 KB

# %% [markdown]
# # Call Count per day

# %%
df2 = df1.copy()

# %%
df2['date'] = df2['Activity date'].dt.date

# %%
df2.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2023-11-01 00:52:00            NaN      00:00:40          Sal Berdayi
# 1 2023-11-01 00:53:00            NaN      00:00:25          Sal Berdayi
# 2 2023-11-01 00:53:00            NaN      00:00:12          Sal Berdayi
# 3 2023-11-01 00:54:00            NaN      00:00:21          Sal Berdayi
# 4 2023-11-01 09:13:00            NaN      00:01:00         Karen Parker
#
#          date
# 0  2023-11-01
# 1  2023-11-01
# 2  2023-11-01
# 3  2023-11-01
# 4  2023-11-01

# %%
daily_calls = (
    df2.groupby(df2['Activity date'].dt.date)
    .size()
    .reset_index(name='call_count')
    .rename(columns={'Activity date': 'date'})
)

# %%
daily_calls.head()
# Out:
#          date  call_count
# 0  2023-11-01         626
# 1  2023-11-02         616
# 2  2023-11-03         350
# 3  2023-11-04          80
# 4  2023-11-05         104

# %%
plt.figure()
plt.plot(daily_calls['date'], daily_calls['call_count'],color='blue')

plt.fill_between(daily_calls['date'], daily_calls['call_count'], color='orange', alpha=0.6)

plt.title("Daily Call Volume")
plt.xlabel("Date")
plt.ylabel("Number of Calls")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Count of Call in Weekdays

# %%
df1['day'] = df1['Activity date'].dt.day_name()

# %%
df1.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2023-11-01 00:52:00            NaN      00:00:40          Sal Berdayi
# 1 2023-11-01 00:53:00            NaN      00:00:25          Sal Berdayi
# 2 2023-11-01 00:53:00            NaN      00:00:12          Sal Berdayi
# 3 2023-11-01 00:54:00            NaN      00:00:21          Sal Berdayi
# 4 2023-11-01 09:13:00            NaN      00:01:00         Karen Parker
#
#          day
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4  Wednesday

# %%
day_Counts = df1["day"].value_counts()
day_Counts.plot(kind='bar')
ax= day_Counts.plot(kind='bar')

for i,v in enumerate(day_Counts):
    ax.text(i, v+1, str(v), ha="center")

plt.title("count of calls in day")
plt.xlabel("day")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Inbound VS Outbound

# %%
IN_OUT_COUNT = df1['Call direction'].value_counts()
IN_OUT_COUNT.plot(kind='bar')
ax = IN_OUT_COUNT.plot(kind='bar')

for i,v in enumerate(IN_OUT_COUNT):
    ax.text(i,v+1, str(v), ha="center")

plt.title("Count Inbound & Outbound call")
plt.xlabel('IN OR OUT')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Count 00 Duration for Bound

# %%
N_B = df1[(df1['Call duration'] == "00:00:00")]

# %%
N_B_Counts = N_B['Call direction'].value_counts()
N_B_Counts.plot(kind="bar")
ax = N_B_Counts.plot(kind="bar")

for i,v in enumerate(N_B_Counts):
    ax.text(i, v+1, str(v), ha="center")

plt.title("Count 00 Duration for Bound")
plt.xlabel("Bound")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 N_B_Counts = N_B['Call direction'].value_counts()
# ----> 2 N_B_Counts.plot(kind="bar")
#       3 ax = N_B_Counts.plot(kind="bar")
#       5 for i,v in enumerate(N_B_Counts):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#      73 return plot_obj.result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:525, in MPLPlot.generate(self)
#     523 for ax in self.axes:
#     524     self._post_plot_logic_common(ax)
# --> 525     self._post_plot_logic(ax, self.data)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:2049, in BarPlot._post_plot_logic(self, ax, data)
#    2046 else:
#    2047     str_index = [pprint_thing(key) for key in range(data.shape[0])]
# -> 2049 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    2050 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    2052 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# # Call duration NULL but have call direction

# %%
df1[(df1['Call duration'].isnull()) & (df1['Call direction'].notnull())]
# Out:
#             Activity date Call direction Call duration Activity assigned to  \
# 5     2023-11-01 09:26:00        Inbound           NaN         Robin Stoehr
# 7     2023-11-01 09:32:00        Inbound           NaN         Robin Stoehr
# 8     2023-11-01 09:34:00        Inbound           NaN         Robin Stoehr
# 25    2023-11-01 10:17:00       Outbound           NaN         Robin Stoehr
# 145   2023-11-01 14:10:00       Outbound           NaN         Robin Stoehr
# ...                   ...            ...           ...                  ...
# 12493 2023-11-30 11:46:00        Inbound           NaN         Robin Stoehr
# 12534 2023-11-30 12:31:00       Outbound           NaN        Keith Antonio
# 12539 2023-11-30 12:34:00       Outbound           NaN        Keith Antonio
# 12734 2023-11-30 16:01:00       Outbound           NaN        Keith Antonio
# 12750 2023-11-30 16:13:00       Outbound           NaN         Robin Stoehr
#
#              day
# 5      Wednesday
# 7      Wednesday
# 8      Wednesday
# 25     Wednesday
# 145    Wednesday
# ...          ...
# 12493   Thursday
# 12534   Thursday
# 12539   Thursday
# 12734   Thursday
# 12750   Thursday
#
# [188 rows x 5 columns]

# %%
df4 = df1.copy()

# %%
df4.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2023-11-01 00:52:00            NaN      00:00:40          Sal Berdayi
# 1 2023-11-01 00:53:00            NaN      00:00:25          Sal Berdayi
# 2 2023-11-01 00:53:00            NaN      00:00:12          Sal Berdayi
# 3 2023-11-01 00:54:00            NaN      00:00:21          Sal Berdayi
# 4 2023-11-01 09:13:00            NaN      00:01:00         Karen Parker
#
#          day
# 0  Wednesday
# 1  Wednesday
# 2  Wednesday
# 3  Wednesday
# 4  Wednesday

# %%
df4['Call duration'] = (
    pd.to_timedelta(df4['Call duration'], errors = 'coerce')
    .dt.total_seconds()/60
)

# %%
(df4['Call duration'] == 0).sum()
# Out:
# 0

# %%
df4['Call duration'] = df4['Call duration'].fillna(0)

# %%
df4 = df4.dropna(subset = ['Call direction'])

# %%
(df4['Call duration'] == 0).sum()
# Out:
# 188

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 738 entries, 5 to 12854
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         738 non-null    datetime64[us]
#  1   Call direction        738 non-null    str
#  2   Call duration         738 non-null    float64
#  3   Activity assigned to  738 non-null    str
#  4   day                   738 non-null    str
# dtypes: datetime64[us](1), float64(1), str(3)
# memory usage: 54.6 KB

# %% [markdown]
# # Working Call Assigner

# %%
df1['Activity assigned to'].nunique()
# Out:
# 21

# %%
df1['Activity assigned to'].unique()
# Out:
# <ArrowStringArray>
# [        'Sal Berdayi',        'Karen Parker',        'Robin Stoehr',
#       'Cameron Dudley',       'Oliver Martin',       'Pete Clements',
#          'Adrian Tran',    'Colby Rintharamy',        'Louis Maciel',
#         'David Valdez',    'Vladimir Suparto',      'David Banister',
#          'Jinky Rance',       'Keith Antonio',        'Ray Levesque',
#  'Demmie Rose Tamonan',        'Dioni Canega',    'Chrystel Manabat',
#            'Terry Kim',         'Paol Guzman',       'Sam Steindorf']
# Length: 21, dtype: str

# %%
ASSI_COUNT = df1['Activity assigned to'].value_counts().head(5)

ax = ASSI_COUNT.plot(kind='barh')

for i,v in enumerate(ASSI_COUNT):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 Call Assign")
plt.xlabel("Count")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Max Call Duration

# %%
df4['Call duration'].max()
# Out:
# 73.3

# %%
top5 = df4.nlargest(5, "Call duration")

ax = top5.set_index('Activity assigned to')['Call duration'].sort_values().plot(kind="barh")

for i, v in enumerate(top5["Call duration"].sort_values()):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 longest Call Duration")
plt.xlabel("Duration (minutes)")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Only Weekdays Call Volume

# %%
df3 = df1.copy()

# %%
df3 = df3[~df3['day'].isin(['Saturday', 'Sunday'])]

# %%
df3['day'].unique()
# Out:
# <ArrowStringArray>
# ['Wednesday', 'Thursday', 'Friday', 'Monday', 'Tuesday']
# Length: 5, dtype: str

# %%
week_day_calls=(
    df3.groupby(df3['Activity date'].dt.date)
    .size()
    .reset_index(name='call_count')
    .rename(columns={'Activity date': 'date'})
)

# %%
plt.figure()
plt.plot(week_day_calls['date'], week_day_calls['call_count'], color='blue')

plt.fill_between(week_day_calls['date'], week_day_calls['call_count'],color='green', alpha=0.6)

plt.title("Week Days Call Volume")
plt.xlabel("date")
plt.ylabel("Number of calls")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # WEEKEND TIME DURATION

# %%
df5=df4.copy()

# %%
df5 = df5[~df5['day'].isin(['Monday', 'Thursday', 'Friday', 'Wednesday', 'Tuesday'])]

# %%
df5.head()
# Out:
#            Activity date Call direction  Call duration Activity assigned to  \
# 1739 2023-11-05 12:11:00       Outbound       0.000000        Keith Antonio
# 1762 2023-11-05 18:56:00       Outbound       0.000000        Keith Antonio
# 1767 2023-11-05 19:03:00       Outbound       0.000000        Keith Antonio
# 8241 2023-11-19 14:01:00       Outbound      13.366667        Keith Antonio
# 8253 2023-11-19 14:15:00       Outbound       0.000000        Keith Antonio
#
#          day
# 1739  Sunday
# 1762  Sunday
# 1767  Sunday
# 8241  Sunday
# 8253  Sunday

# %%
top5 = df5.nlargest(5, "Call duration")

ax = top5.set_index("Activity assigned to")["Call duration"].sort_values().plot(kind="barh")

for i, v in enumerate(top5["Call duration"].sort_values()):
    ax.text(v + 0.1, i, str(v), va="center")

plt.title("Top 5 Longest Call Duration")
plt.xlabel("Duration (minutes)")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Top 5 Weekend Call Assigner

# %%
ASSI_COUNT = df5['Activity assigned to'].value_counts().head(5)

ax = ASSI_COUNT.plot(kind='barh')

for i,v in enumerate(ASSI_COUNT):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 Call Assign")
plt.xlabel("Count")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Average Call Duration

# %%
df4["Call duration"].mean()
# Out:
# 3.33046522131888

# %%
df4["Call duration"].median()
# Out:
# 0.9666666666666667

# %% [markdown]
# # Top 5 Peak Call date

# %%
daily_calls = df.groupby(df2["Activity date"].dt.date).size()

# %%
top5 = daily_calls.sort_values(ascending=False).head(5)

# %%
ax = top5.sort_index().plot(kind="bar", color="brown")

for i, v in enumerate(top5.sort_index()):
    ax.text(i, v + 0.5, str(v), ha="center", fontsize=10)
    
plt.title("Top 5 Peak Call Count In NOV 2023")
plt.xlabel("Date")
plt.ylabel("Call Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
