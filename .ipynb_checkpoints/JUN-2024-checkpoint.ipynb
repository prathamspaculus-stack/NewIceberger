# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("06-2024.csv")

# %%
df.head()
# Out:
#      Record ID     Activity date Call direction Call duration  \
# 0  53721402546  2024-06-01 09:06       Outbound      00:02:14
# 1  53721656442  2024-06-01 09:25       Outbound      00:00:30
# 2  53721997654  2024-06-01 10:00       Outbound      00:24:07
# 3  53722303027  2024-06-01 10:07            NaN      00:27:46
# 4  53721762885  2024-06-01 10:16       Outbound      00:00:27
#
#    hs_call_outcome Activity assigned to
# 0              NaN        Oliver Martin
# 1              NaN        Garrett Evans
# 2              NaN        Keith Antonio
# 3              NaN        Sam Steindorf
# 4              NaN        Garrett Evans

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7693 entries, 0 to 7692
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Record ID             7693 non-null   int64
#  1   Activity date         7693 non-null   str
#  2   Call direction        6316 non-null   str
#  3   Call duration         6606 non-null   str
#  4   hs_call_outcome       0 non-null      float64
#  5   Activity assigned to  7481 non-null   str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 672.6 KB

# %%
df1 = df.drop(columns=['hs_call_outcome', 'Record ID'])

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7693 entries, 0 to 7692
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         7693 non-null   str
#  1   Call direction        6316 non-null   str
#  2   Call duration         6606 non-null   str
#  3   Activity assigned to  7481 non-null   str
# dtypes: str(4)
# memory usage: 552.4 KB

# %%
df1['Activity date'] = pd.to_datetime(
    df1['Activity date'],
    format="%Y-%m-%d %H:%M",
    errors="coerce"
)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7693 entries, 0 to 7692
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         7693 non-null   datetime64[us]
#  1   Call direction        6316 non-null   str
#  2   Call duration         6606 non-null   str
#  3   Activity assigned to  7481 non-null   str
# dtypes: datetime64[us](1), str(3)
# memory usage: 432.2 KB

# %% [markdown]
# # Call Count per day

# %%
df2 = df1.copy()

# %%
df2['date'] = df2['Activity date'].dt.date

# %%
df2.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2024-06-01 09:06:00       Outbound      00:02:14        Oliver Martin
# 1 2024-06-01 09:25:00       Outbound      00:00:30        Garrett Evans
# 2 2024-06-01 10:00:00       Outbound      00:24:07        Keith Antonio
# 3 2024-06-01 10:07:00            NaN      00:27:46        Sam Steindorf
# 4 2024-06-01 10:16:00       Outbound      00:00:27        Garrett Evans
#
#          date
# 0  2024-06-01
# 1  2024-06-01
# 2  2024-06-01
# 3  2024-06-01
# 4  2024-06-01

# %%
daily_calls = (
    df2.groupby(df2['Activity date'].dt.date)
    .size()
    .reset_index(name='call_count')
    .rename(columns= {'Activity date': 'date'})
)

# %%
daily_calls.head()
# Out:
#          date  call_count
# 0  2024-06-01          48
# 1  2024-06-02          24
# 2  2024-06-03         375
# 3  2024-06-04         341
# 4  2024-06-05         338

# %%
plt.figure()
plt.plot(daily_calls['date'], daily_calls['call_count'], color="blue")

plt.fill_between(daily_calls['date'], daily_calls['call_count'], color ="orange", alpha=0.6)

plt.title('Daily Call Volume')
plt.xlabel('Date')
plt.ylabel('Number of Calls')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Count of Call in Weekdays

# %%
df1['day'] = df1['Activity date'].dt.day_name()

# %%
df1.head()
# Out:
#         Activity date Call direction Call duration Activity assigned to  \
# 0 2024-06-01 09:06:00       Outbound      00:02:14        Oliver Martin
# 1 2024-06-01 09:25:00       Outbound      00:00:30        Garrett Evans
# 2 2024-06-01 10:00:00       Outbound      00:24:07        Keith Antonio
# 3 2024-06-01 10:07:00            NaN      00:27:46        Sam Steindorf
# 4 2024-06-01 10:16:00       Outbound      00:00:27        Garrett Evans
#
#         day
# 0  Saturday
# 1  Saturday
# 2  Saturday
# 3  Saturday
# 4  Saturday

# %%
day_Counts = df1["day"].value_counts()
day_Counts.plot(kind='bar')
ax= day_Counts.plot(kind='bar')

for i,v in enumerate(day_Counts):
    ax.text(i, v+1, str(v), ha="center")

plt.title("count of calls in day")
plt.xlabel("day")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Inbound VS Outbound

# %%
IN_OUT_COUNT = df1['Call direction'].value_counts()
IN_OUT_COUNT.plot(kind='bar')
ax = IN_OUT_COUNT.plot(kind='bar')

for i,v in enumerate(IN_OUT_COUNT):
    ax.text(i, v+1, str(v), ha="center")

plt.title("Count Inbound & Outbound call")
plt.xlabel("IN OR OUT")
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Count 00 Duration for Bound

# %%
N_B = df1[(df1['Call duration'] == "00:00:00")]

# %%
N_B_Counts = N_B['Call direction'].value_counts()
N_B_Counts.plot(kind="bar")
ax = N_B_Counts.plot(kind="bar")

for i,v in enumerate(N_B_Counts):
    ax.text(i, v+1, str(v), ha="center")

plt.title("Count 00 Duration for Bound")
plt.xlabel("Bound")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Call duration NULL but have Call direction

# %%
df1[(df1['Call duration'].isnull()) & (df1['Call direction'].notnull())]
# Out:
#            Activity date Call direction Call duration Activity assigned to  \
# 450  2024-06-04 09:05:00       Outbound           NaN        Sam Steindorf
# 490  2024-06-04 11:09:00       Outbound           NaN       Cameron Dudley
# 494  2024-06-04 11:14:00       Outbound           NaN       Cameron Dudley
# 521  2024-06-04 11:43:00       Outbound           NaN       Cameron Dudley
# 806  2024-06-05 10:09:00       Outbound           NaN       Cameron Dudley
# 1129 2024-06-06 09:21:00       Outbound           NaN        Sam Steindorf
# 1144 2024-06-06 10:06:00       Outbound           NaN         David Valdez
# 1321 2024-06-06 14:54:00        Inbound           NaN       Cameron Dudley
# 1322 2024-06-06 14:57:00       Outbound           NaN       Cameron Dudley
# 2017 2024-06-10 10:43:00       Outbound           NaN       Cameron Dudley
# 2434 2024-06-11 10:14:00       Outbound           NaN       Cameron Dudley
# 2436 2024-06-11 10:16:00       Outbound           NaN       Cameron Dudley
# 2527 2024-06-11 13:14:00       Outbound           NaN        Keith Antonio
# 3221 2024-06-13 10:26:00       Outbound           NaN       Cameron Dudley
# 4755 2024-06-18 20:30:00       Outbound           NaN        Sam Steindorf
# 4965 2024-06-19 15:31:00       Outbound           NaN         David Valdez
# 5662 2024-06-21 17:02:00       Outbound           NaN        Sam Steindorf
# 7592 2024-06-29 15:07:00       Outbound           NaN         David Valdez
#
#             day
# 450     Tuesday
# 490     Tuesday
# 494     Tuesday
# 521     Tuesday
# 806   Wednesday
# 1129   Thursday
# 1144   Thursday
# 1321   Thursday
# 1322   Thursday
# 2017     Monday
# 2434    Tuesday
# 2436    Tuesday
# 2527    Tuesday
# 3221   Thursday
# 4755    Tuesday
# 4965  Wednesday
# 5662     Friday
# 7592   Saturday

# %%
df4 = df1.copy()

# %%
df4['Call duration'] = (
    pd.to_timedelta(df4['Call duration'], errors = 'coerce')
    .dt.total_seconds()/60
)

# %%
(df4['Call duration'] == 0).sum()
# Out:
# 731

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7693 entries, 0 to 7692
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         7693 non-null   datetime64[us]
#  1   Call direction        6316 non-null   str
#  2   Call duration         6606 non-null   float64
#  3   Activity assigned to  7481 non-null   str
#  4   day                   7693 non-null   str
# dtypes: datetime64[us](1), float64(1), str(3)
# memory usage: 493.7 KB

# %%
df4['Call duration'] = df4['Call duration'].fillna(0)

# %%
df4 = df4.dropna(subset = ['Call direction'])

# %%
(df4['Call duration'] == 0).sum()
# Out:
# 749

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6316 entries, 0 to 7692
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Activity date         6316 non-null   datetime64[us]
#  1   Call direction        6316 non-null   str
#  2   Call duration         6316 non-null   float64
#  3   Activity assigned to  6114 non-null   str
#  4   day                   6316 non-null   str
# dtypes: datetime64[us](1), float64(1), str(3)
# memory usage: 462.9 KB

# %% [markdown]
# # Working Call Assigner

# %%
df1['Activity assigned to'].nunique()
# Out:
# 20

# %%
df1['Activity assigned to'].unique()
# Out:
# <ArrowStringArray>
# [    'Oliver Martin',     'Garrett Evans',     'Keith Antonio',
#      'Sam Steindorf',      'David Valdez',                 nan,
#         'Tyler Jury',      'Robin Stoehr',    'Cameron Dudley',
#     'David Banister',     'Tanner Schunk',       'Paol Guzman',
#       'Karen Parker',         'Terry Kim',      'Stephen Tarr',
#       'Bill Goodwin',         'Juan Calo',  'Chrystel Manabat',
#  'Brittany Digiulio',   'Adonis Baybayan',        'Henry Good']
# Length: 21, dtype: str

# %%
ASSI_COUNT = df1['Activity assigned to'].value_counts().head(5)

ax = ASSI_COUNT.plot(kind='barh')

for i,v in enumerate(ASSI_COUNT):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 Call Assign")
plt.xlabel("Count")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # MAX CALL DURATION

# %%
df4['Call duration'].max()
# Out:
# 98.55

# %%
top5 = df4.nlargest(5, "Call duration")

ax = top5.set_index('Activity assigned to')['Call duration'].sort_values().plot(kind="barh")

for i, v in enumerate(top5["Call duration"].sort_values()):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 longest Call Duration")
plt.xlabel("Duration (minutes)")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Only Weekdays Call Volume

# %%
df3 = df1.copy()

# %%
df3 = df3[~df3['day'].isin(['Saturday', 'Sunday'])]

# %%
df3['day'].unique()
# Out:
# <ArrowStringArray>
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
# Length: 5, dtype: str

# %%
week_day_calls=(
    df3.groupby(df3['Activity date'].dt.date)
    .size()
    .reset_index(name='call_count')
    .rename(columns={'Activity date': 'date'})
)

# %%
plt.figure()
plt.plot(week_day_calls['date'], week_day_calls['call_count'], color='blue')

plt.fill_between(week_day_calls['date'],week_day_calls['call_count'], color='green', alpha=0.6)

plt.title("Weekdays Call Volume")
plt.xlabel('Date')
plt.ylabel('Number of Calls')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # WEEKEND TIME DURATION

# %%
df5=df4.copy()

# %%
df5 = df5[~df5['day'].isin(['Monday', 'Thursday', 'Friday', 'Wednesday', 'Tuesday'])]

# %%
df5.head()
# Out:
#         Activity date Call direction  Call duration Activity assigned to  \
# 0 2024-06-01 09:06:00       Outbound       2.233333        Oliver Martin
# 1 2024-06-01 09:25:00       Outbound       0.500000        Garrett Evans
# 2 2024-06-01 10:00:00       Outbound      24.116667        Keith Antonio
# 4 2024-06-01 10:16:00       Outbound       0.450000        Garrett Evans
# 5 2024-06-01 10:24:00       Outbound       0.550000        Keith Antonio
#
#         day
# 0  Saturday
# 1  Saturday
# 2  Saturday
# 4  Saturday
# 5  Saturday

# %%
top5 = df5.nlargest(5, "Call duration")

ax = top5.set_index("Activity assigned to")["Call duration"].sort_values().plot(kind="barh")

for i, v in enumerate(top5["Call duration"].sort_values()):
    ax.text(v + 0.1, i, str(v), va="center")

plt.title("Top 5 Longest Call Duration")
plt.xlabel("Duration (minutes)")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Top 5 Weekend Call Assigner

# %%
ASSI_COUNT = df5['Activity assigned to'].value_counts().head(5)

ax = ASSI_COUNT.plot(kind='barh')

for i,v in enumerate(ASSI_COUNT):
    ax.text(v+1, i, str(v), va="center")

plt.title("Top 5 Call Assign")
plt.xlabel("Count")
plt.ylabel("Assigner")
plt.show()

# %% [markdown]
# # Without Call Assigner Calls

# %%
df6 = df3.copy()

# %%
df6['month'] = df6['Activity date'].dt.month_name()

# %%
no_assigner_calls = df6[df6["Activity assigned to"].isna()]

# %%
month_counts = no_assigner_calls["month"].value_counts()
month_counts.plot(kind="bar")
ax = month_counts.plot(kind="bar")

for i, v in enumerate(month_counts):
    ax.text(i, v + 1, str(v), ha="center")

plt.title("Count of calls Without Assigner")
plt.xlabel("Month")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Top 5 Peak Call Date

# %%
daily_calls = df.groupby(df2["Activity date"].dt.date).size()

# %%
top5 = daily_calls.sort_values(ascending=False).head(5)

# %%
ax = top5.sort_index().plot(kind="bar", color="brown")

for i, v in enumerate(top5.sort_index()):
    ax.text(i, v + 0.5, str(v), ha="center", fontsize=10)
    
plt.title("Top 5 Peak Call Count In JUN 2024")
plt.xlabel("Date")
plt.ylabel("Call Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
